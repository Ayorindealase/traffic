# %%
import pandas as pd
import numpy as np

df1=pd.read_excel("Downloads/Tdm.xslx","Sheet1")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-dcc92def8edb> in <module>
#       2 import numpy as np
#       3
# ----> 4 df1=pd.read_excel("Downloads/Tdm.xslx","Sheet1")
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     297                 )
#     298                 warnings.warn(msg, FutureWarning, stacklevel=stacklevel)
# --> 299             return func(*args, **kwargs)
#     300
#     301         return wrapper
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, squeeze, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, thousands, comment, skipfooter, convert_float, mangle_dupe_cols, storage_options)
# ...

# %%
a=int(input("""Location:
Press 1) for Allen Avenue
Press 2) for Awolowo Road (Sectariat)
Press 3) for Aromire street 
Press 4) Awolowo road(From Ikeja inside)>>>>>>>>>>>>>>>>>>>>> """))
if a==1:
    print("You have decided to calculate the traffic time for Allen Avenue")
elif a==2:
     print("You have decided to calculate the traffic time for Awolowo road(From sectariat)")
elif a==3:
        print("You have decided to calculate the traffic time for Aromire street")
elif a==4:
        print("You have decided to calculate the traffic time for Awolowo road(From Ikeja inside)")
else:
    print("Wrong input try again!!!!!")

b=int(input(""""Press 0) For Morning
       Press 1) for evening>>>>>."""))

time=input("Enter the time(seperated by comma(6:30 is 6,30))>>>>")
day=int(input(""""Enter weekday()>>>>:
    Enter 1 for Monday
    Enter 2 for Tuesday
    Enter 3 for Wednesday
    Enter 4 for Thursday
    Enter 5 for Friday
    Enter 6 for Weekend>>>>>>>>>:"""))
if day==1 and time=="6,30":
            m=df1.iloc[0]["WKD 1"]
            n=dfa.iloc[1]["Intensity"]
            t=m/(n*math.factorial(3))
            print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==1 and time=="6,32":
            m=df1.iloc[1]["WKD 1"]
            n=dfa.iloc[1]["Intensity"]
            t=m/(n*math.factorial(3))
            print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==1 and time=="6,34":
    m=df1.iloc[2]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==1 and time=="6,36":
    m=df1.iloc[3]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==1 and time=="6,38":
    m=df1.iloc[4]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==1 and time=="6,40":
    m=df1.iloc[5]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="6,42":
    m=df1.iloc[6]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="6,44":
    m=df1.iloc[7]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="6,46":
    m=df1.iloc[8]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="6,48":
    m=df1.iloc[9]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="6,50":
    m=df1.iloc[10]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="6,52":
    m=df1.iloc[11]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="6,54":
    m=df1.iloc[12]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="6,56":
    m=df1.iloc[13]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="6,58":
    m=df1.iloc[14]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="7,00" or "7":
    m=df1.iloc[15]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="7,02":
    m=df1.iloc[16]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="7,04":
    m=df1.iloc[17]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="7,06":
    m=df1.iloc[18]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,08":
        m=df1.iloc[19]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,10":
        m=df1.iloc[20]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,12":
        m=df1.iloc[21]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,14":
        m=df1.iloc[22]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,16":
        m=df1.iloc[23]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,18":
        m=df1.iloc[24]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,20":
        m=df1.iloc[25]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,22":
        m=df1.iloc[26]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,24":
        m=df1.iloc[27]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,26":
        m=df1.iloc[28]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,28":
        m=df1.iloc[29]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,30":
        m=df1.iloc[30]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,32":
        m=df1.iloc[31]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,34":
        m=df1.iloc[32]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,36":
        m=df1.iloc[33]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,38":
        m=df1.iloc[34]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,40":
        m=df1.iloc[35]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,42":
        m=df1.iloc[36]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,44":
        m=df1.iloc[37]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,46":
        m=df1.iloc[38]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
    if day==1 and time=="7,48":
        m=df1.iloc[39]["WKD 1"]
        n=dfa.iloc[1]["Intensity"]
        t=m/(n*math.factorial(3))
        print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="7,50":
    m=df1.iloc[40]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="7,52":
    m=df1.iloc[41]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="7,54":
    m=df1.iloc[42]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="7,56":
    m=df1.iloc[0]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="7,58":
    m=df1.iloc[43]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,00":
    m=df1.iloc[44]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,02":
    m=df1.iloc[45]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,04":
    m=df1.iloc[46]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,06":
    m=df1.iloc[47]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,08":
    m=df1.iloc[48]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,10":
    m=df1.iloc[49]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,12":
    m=df1.iloc[50]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,14":
    m=df1.iloc[51]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,16":
    m=df1.iloc[52]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,18":
    m=df1.iloc[53]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,20":
    m=df1.iloc[54]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,22":
    m=df1.iloc[55]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,24":
    m=df1.iloc[56]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,26":
    m=df1.iloc[57]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,28":
    m=df1.iloc[58]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,30":
    m=df1.iloc[59]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,32":
    m=df1.iloc[60]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,34":
    m=df1.iloc[61]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,36":
    m=df1.iloc[62]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,38":
    m=df1.iloc[63]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,40":
    m=df1.iloc[64]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,42":
    m=df1.iloc[65]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,44":
    m=df1.iloc[66]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,46":
    m=df1.iloc[67]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,48":
    m=df1.iloc[68]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,50":
    m=df1.iloc[69]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,52":
    m=df1.iloc[70]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,54":
    m=df1.iloc[71]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,56":
    m=df1.iloc[72]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,58":
    m=df1.iloc[73]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,58":
    m=df1.iloc[73]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="9,00":
    m=df1.iloc[74]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
else:
    print("Input wrong, Kindly try again!!!!!!")

#For Weekday 2
if day==2 and time=="6,30":
    m=df1.iloc[0]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==2 and time=="6,32":
    m=df1.iloc[1]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==2 and time=="6,34":
    m=df1.iloc[2]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==2 and time=="6,36":
    m=df1.iloc[3]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==2 and time=="6,38":
    m=df1.iloc[4]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==2 and time=="6,40":
    m=df1.iloc[5]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="6,42":
    m=df1.iloc[6]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="6,44":
    m=df1.iloc[7]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="6,46":
    m=df1.iloc[8]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="6,48":
    m=df1.iloc[9]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="6,50":
    m=df1.iloc[10]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="6,52":
    m=df1.iloc[11]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="6,54":
    m=df1.iloc[12]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="6,56":
    m=df1.iloc[13]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="6,58":
    m=df1.iloc[14]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,00" or "7":
    m=df1.iloc[15]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,02":
    m=df1.iloc[16]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,04":
    m=df1.iloc[17]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,06":
    m=df1.iloc[18]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="7,08":
    m=df1.iloc[19]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,10":
    m=df1.iloc[20]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,12":
    m=df1.iloc[21]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,14":
    m=df1.iloc[22]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,16":
    m=df1.iloc[23]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,18":
    m=df1.iloc[24]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,20":
    m=df1.iloc[25]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,22":
    m=df1.iloc[26]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,24":
    m=df1.iloc[27]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,26":
    m=df1.iloc[28]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,28":
    m=df1.iloc[29]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,30":
    m=df1.iloc[30]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,32":
    m=df1.iloc[31]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,34":
    m=df1.iloc[32]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,36":
    m=df1.iloc[33]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,38":
    m=df1.iloc[34]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,40":
    m=df1.iloc[35]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,42":
    m=df1.iloc[36]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,44":
    m=df1.iloc[37]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,46":
    m=df1.iloc[38]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,48":
    m=df1.iloc[39]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,50":
    m=df1.iloc[40]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,52":
    m=df1.iloc[41]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,54":
    m=df1.iloc[42]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,56":
    m=df1.iloc[0]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="7,58":
    m=df1.iloc[43]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,00":
    m=df1.iloc[44]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,02":
    m=df1.iloc[45]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,04":
    m=df1.iloc[46]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,06":
    m=df1.iloc[47]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,08":
    m=df1.iloc[48]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,10":
    m=df1.iloc[49]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,12":
    m=df1.iloc[50]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,14":
    m=df1.iloc[51]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,16":
    m=df1.iloc[52]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,18":
    m=df1.iloc[53]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,20":
    m=df1.iloc[54]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,22":
    m=df1.iloc[55]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,24":
    m=df1.iloc[56]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,26":
    m=df1.iloc[57]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,28":
    m=df1.iloc[58]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,30":
    m=df1.iloc[59]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,32":
    m=df1.iloc[60]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,34":
    m=df1.iloc[61]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,36":
    m=df1.iloc[62]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,38":
    m=df1.iloc[63]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,40":
    m=df1.iloc[64]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,42":
    m=df1.iloc[65]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,44":
    m=df1.iloc[66]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,46":
    m=df1.iloc[67]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,48":
    m=df1.iloc[68]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,50":
    m=df1.iloc[69]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,52":
    m=df1.iloc[70]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,54":
    m=df1.iloc[71]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,56":
    m=df1.iloc[72]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,58":
    m=df1.iloc[73]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="8,58":
    m=df1.iloc[73]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==2 and time=="9,00":
    m=df1.iloc[74]["WKD 2"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
#For Weekday 3
if day==3 and time=="6,30":
    m=df1.iloc[0]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==3 and time=="6,32":
    m=df1.iloc[1]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==3 and time=="6,34":
    m=df1.iloc[2]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==3 and time=="6,36":
    m=df1.iloc[3]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==3 and time=="6,38":
    m=df1.iloc[4]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==3 and time=="6,40":
    m=df1.iloc[5]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="6,42":
    m=df1.iloc[6]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="6,44":
    m=df1.iloc[7]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="6,46":
    m=df1.iloc[8]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="6,48":
    m=df1.iloc[9]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="6,50":
    m=df1.iloc[10]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="6,52":
    m=df1.iloc[11]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="6,54":
    m=df1.iloc[12]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="6,56":
    m=df1.iloc[13]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="6,58":
    m=df1.iloc[14]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,00" or "7":
    m=df1.iloc[15]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,02":
    m=df1.iloc[16]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,04":
    m=df1.iloc[17]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,06":
    m=df1.iloc[18]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,08":
    m=df1.iloc[19]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,10":
    m=df1.iloc[20]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,12":
    m=df1.iloc[21]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,14":
    m=df1.iloc[22]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,16":
    m=df1.iloc[23]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,18":
    m=df1.iloc[24]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,20":
    m=df1.iloc[25]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="7,22":
    m=df1.iloc[26]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,24":
    m=df1.iloc[27]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,26":
    m=df1.iloc[28]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,28":
    m=df1.iloc[29]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,30":
    m=df1.iloc[30]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="7,32":
    m=df1.iloc[31]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,34":
    m=df1.iloc[32]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,36":
    m=df1.iloc[33]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,38":
    m=df1.iloc[34]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,40":
    m=df1.iloc[35]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,42":
    m=df1.iloc[36]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,44":
    m=df1.iloc[37]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,46":
    m=df1.iloc[38]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,48":
    m=df1.iloc[39]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,50":
    m=df1.iloc[40]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,52":
    m=df1.iloc[41]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,54":
    m=df1.iloc[42]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,56":
    m=df1.iloc[0]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="7,58":
    m=df1.iloc[43]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,00":
    m=df1.iloc[44]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,02":
    m=df1.iloc[45]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,04":
    m=df1.iloc[46]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,06":
    m=df1.iloc[47]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,08":
    m=df1.iloc[48]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,10":
    m=df1.iloc[49]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="8,12":
    m=df1.iloc[50]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,14":
    m=df1.iloc[51]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,16":
    m=df1.iloc[52]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,18":
    m=df1.iloc[53]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,20":
    m=df1.iloc[54]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,22":
    m=df1.iloc[55]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,24":
    m=df1.iloc[56]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,26":
    m=df1.iloc[57]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,28":
    m=df1.iloc[58]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,30":
    m=df1.iloc[59]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,32":
    m=df1.iloc[60]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,34":
    m=df1.iloc[61]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,36":
    m=df1.iloc[62]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,38":
    m=df1.iloc[63]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,40":
    m=df1.iloc[64]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,42":
    m=df1.iloc[65]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,44":
    m=df1.iloc[66]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,46":
    m=df1.iloc[67]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,48":
    m=df1.iloc[68]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,50":
    m=df1.iloc[69]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,52":
    m=df1.iloc[70]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,54":
    m=df1.iloc[71]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,56":
    m=df1.iloc[72]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,58":
    m=df1.iloc[73]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="8,58":
    m=df1.iloc[73]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==3 and time=="9,00":
    m=df1.iloc[74]["WKD 3"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
#For weekday 4
if day==4 and time=="6,30":
    m=df1.iloc[0]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==4 and time=="6,32":
    m=df1.iloc[1]["WKD4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==4 and time=="6,34":
    m=df1.iloc[2]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==4 and time=="6,36":
    m=df1.iloc[3]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==4 and time=="6,38":
    m=df1.iloc[4]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==4 and time=="6,40":
    m=df1.iloc[5]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="6,42":
    m=df1.iloc[6]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="6,44":
    m=df1.iloc[7]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="6,46":
    m=df1.iloc[8]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="6,48":
    m=df1.iloc[9]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="6,50":
    m=df1.iloc[10]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==1 and time=="6,52":
    m=df1.iloc[11]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="6,54":
    m=df1.iloc[12]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="6,56":
    m=df1.iloc[13]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="6,58":
    m=df1.iloc[14]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,00" or "7":
    m=df1.iloc[15]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,02":
    m=df1.iloc[16]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,04":
    m=df1.iloc[17]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,06":
    m=df1.iloc[18]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,08":
    m=df1.iloc[19]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,10":
    m=df1.iloc[20]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,12":
    m=df1.iloc[21]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,14":
    m=df1.iloc[22]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,16":
    m=df1.iloc[23]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,18":
    m=df1.iloc[24]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,20":
    m=df1.iloc[25]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,22":
    m=df1.iloc[26]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,24":
    m=df1.iloc[27]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,26":
    m=df1.iloc[28]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,28":
    m=df1.iloc[29]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,30":
    m=df1.iloc[30]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,32":
    m=df1.iloc[31]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,34":
    m=df1.iloc[32]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,36":
    m=df1.iloc[33]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,38":
    m=df1.iloc[34]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,40":
    m=df1.iloc[35]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,42":
    m=df1.iloc[36]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,44":
    m=df1.iloc[37]["WKD 1"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,46":
    m=df1.iloc[38]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,48":
    m=df1.iloc[39]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,50":
    m=df1.iloc[40]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,52":
    m=df1.iloc[41]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,54":
    m=df1.iloc[42]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,56":
    m=df1.iloc[0]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="7,58":
    m=df1.iloc[43]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,00":
    m=df1.iloc[44]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,02":
    m=df1.iloc[45]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,04":
    m=df1.iloc[46]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,06":
    m=df1.iloc[47]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,08":
    m=df1.iloc[48]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,10":
    m=df1.iloc[49]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,12":
    m=df1.iloc[50]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,14":
    m=df1.iloc[51]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,16":
    m=df1.iloc[52]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,18":
    m=df1.iloc[53]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,20":
    m=df1.iloc[54]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,22":
    m=df1.iloc[55]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,24":
    m=df1.iloc[56]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,26":
    m=df1.iloc[57]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,28":
    m=df1.iloc[58]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,30":
    m=df1.iloc[59]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,32":
    m=df1.iloc[60]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,34":
    m=df1.iloc[61]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,36":
    m=df1.iloc[62]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,38":
    m=df1.iloc[63]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,40":
    m=df1.iloc[64]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,42":
    m=df1.iloc[65]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,44":
    m=df1.iloc[66]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,46":
    m=df1.iloc[67]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,48":
    m=df1.iloc[68]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,50":
    m=df1.iloc[69]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,52":
    m=df1.iloc[70]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,54":
    m=df1.iloc[71]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,56":
    m=df1.iloc[72]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,58":
    m=df1.iloc[73]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,58":
    m=df1.iloc[73]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="9,00":
    m=df1.iloc[74]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t,"Seconds")
#Weekday5
if day==5 and time=="6,30":
    m=df1.iloc[0]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==5 and time=="6,32":
    m=df1.iloc[1]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==5 and time=="6,34":
    m=df1.iloc[2]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==4 and time=="6,36":
    m=df1.iloc[3]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==5 and time=="6,38":
    m=df1.iloc[4]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==5 and time=="6,40":
    m=df1.iloc[5]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="6,42":
    m=df1.iloc[6]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="6,44":
    m=df1.iloc[7]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="6,46":
    m=df1.iloc[8]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="6,48":
    m=df1.iloc[9]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="6,50":
    m=df1.iloc[10]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="6,52":
    m=df1.iloc[11]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="6,54":
    m=df1.iloc[12]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="6,56":
    m=df1.iloc[13]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="6,58":
    m=df1.iloc[14]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,00" or "7":
    m=df1.iloc[15]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,02":
    m=df1.iloc[16]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,04":
    m=df1.iloc[17]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,06":
    m=df1.iloc[18]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,08":
    m=df1.iloc[19]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,10":
    m=df1.iloc[20]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,12":
    m=df1.iloc[21]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,14":
    m=df1.iloc[22]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,16":
    m=df1.iloc[23]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,18":
    m=df1.iloc[24]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,20":
    m=df1.iloc[25]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,22":
    m=df1.iloc[26]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,24":
    m=df1.iloc[27]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,26":
    m=df1.iloc[28]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,28":
    m=df1.iloc[29]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,30":
    m=df1.iloc[30]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,32":
    m=df1.iloc[31]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,34":
    m=df1.iloc[32]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,36":
    m=df1.iloc[33]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,38":
    m=df1.iloc[34]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,40":
    m=df1.iloc[35]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,42":
    m=df1.iloc[36]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,44":
    m=df1.iloc[37]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,46":
    m=df1.iloc[38]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,48":
    m=df1.iloc[39]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,50":
    m=df1.iloc[40]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,52":
    m=df1.iloc[41]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,54":
    m=df1.iloc[42]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,56":
    m=df1.iloc[0]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="7,58":
    m=df1.iloc[43]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,00":
    m=df1.iloc[44]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,02":
    m=df1.iloc[45]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,04":
    m=df1.iloc[46]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,06":
    m=df1.iloc[47]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,08":
    m=df1.iloc[48]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,10":
    m=df1.iloc[49]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,12":
    m=df1.iloc[50]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,14":
    m=df1.iloc[51]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,16":
    m=df1.iloc[52]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,18":
    m=df1.iloc[53]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,20":
    m=df1.iloc[54]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,22":
    m=df1.iloc[55]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,24":
    m=df1.iloc[56]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,26":
    m=df1.iloc[57]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,28":
    m=df1.iloc[58]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,30":
    m=df1.iloc[59]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,32":
    m=df1.iloc[60]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,34":
    m=df1.iloc[61]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,36":
    m=df1.iloc[62]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,38":
    m=df1.iloc[63]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,40":
    m=df1.iloc[64]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,42":
    m=df1.iloc[65]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,44":
    m=df1.iloc[66]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,46":
    m=df1.iloc[67]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,48":
    m=df1.iloc[68]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,50":
    m=df1.iloc[69]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,52":
    m=df1.iloc[70]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,54":
    m=df1.iloc[71]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,56":
    m=df1.iloc[72]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="8,58":
    m=df1.iloc[73]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==4 and time=="8,58":
    m=df1.iloc[73]["WKD 4"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==5 and time=="9,00":
    m=df1.iloc[74]["WKD 5"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t,"Seconds")
#Weekday6
if day==6 and time=="6,30":
    m=df1.iloc[0]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==6 and time=="6,32":
    m=df1.iloc[1]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==6 and time=="6,34":
    m=df1.iloc[2]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==6 and time=="6,36":
    m=df1.iloc[3]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==6 and time=="6,38":
    m=df1.iloc[4]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
elif day==6 and time=="6,40":
    m=df1.iloc[5]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="6,42":
    m=df1.iloc[6]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="6,44":
    m=df1.iloc[7]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="6,46":
    m=df1.iloc[8]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="6,48":
    m=df1.iloc[9]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="6,50":
    m=df1.iloc[10]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="6,52":
    m=df1.iloc[11]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="6,54":
    m=df1.iloc[12]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="6,56":
    m=df1.iloc[13]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="6,58":
    m=df1.iloc[14]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,00" or "7":
    m=df1.iloc[15]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,02":
    m=df1.iloc[16]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,04":
    m=df1.iloc[17]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,06":
    m=df1.iloc[18]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,08":
    m=df1.iloc[19]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,10":
    m=df1.iloc[20]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,12":
    m=df1.iloc[21]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,14":
    m=df1.iloc[22]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,16":
    m=df1.iloc[23]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,18":
    m=df1.iloc[24]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,20":
    m=df1.iloc[25]["WKD 6"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,22":
    m=df1.iloc[26]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,24":
    m=df1.iloc[27]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,26":
    m=df1.iloc[28]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,28":
    m=df1.iloc[29]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,30":
    m=df1.iloc[30]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,32":
    m=df1.iloc[31]["WKD 6"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,34":
    m=df1.iloc[32]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,36":
    m=df1.iloc[33]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,38":
    m=df1.iloc[34]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,40":
    m=df1.iloc[35]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,42":
    m=df1.iloc[36]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,44":
    m=df1.iloc[37]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,46":
    m=df1.iloc[38]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,48":
    m=df1.iloc[39]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,50":
    m=df1.iloc[40]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,52":
    m=df1.iloc[41]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,54":
    m=df1.iloc[42]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,56":
    m=df1.iloc[0]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="7,58":
    m=df1.iloc[43]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,00":
    m=df1.iloc[44]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,02":
    m=df1.iloc[45]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,04":
    m=df1.iloc[46]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,06":
    m=df1.iloc[47]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,08":
    m=df1.iloc[48]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,10":
    m=df1.iloc[49]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,12":
    m=df1.iloc[50]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,14":
    m=df1.iloc[51]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,16":
    m=df1.iloc[52]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,18":
    m=df1.iloc[53]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,20":
    m=df1.iloc[54]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,22":
    m=df1.iloc[55]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,24":
    m=df1.iloc[56]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,26":
    m=df1.iloc[57]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,28":
    m=df1.iloc[58]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,30":
    m=df1.iloc[59]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,32":
    m=df1.iloc[60]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,34":
    m=df1.iloc[61]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,36":
    m=df1.iloc[62]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,38":
    m=df1.iloc[63]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,40":
    m=df1.iloc[64]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,42":
    m=df1.iloc[65]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,44":
    m=df1.iloc[66]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,46":
    m=df1.iloc[67]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,48":
    m=df1.iloc[68]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,50":
    m=df1.iloc[69]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,52":
    m=df1.iloc[70]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,54":
    m=df1.iloc[71]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,56":
    m=df1.iloc[72]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,58":
    m=df1.iloc[73]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="8,58":
    m=df1.iloc[73]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t, "Seconds")
if day==6 and time=="9,00":
    m=df1.iloc[74]["WE"]
    n=dfa.iloc[1]["Intensity"]
    t=m/(n*math.factorial(3))
    print("The Calculated period is green time is:>>>>",t,"Seconds")
# Out:
# Location:
# Press 1) for Allen Avenue
# Press 2) for Awolowo Road (Sectariat)
# Press 3) for Aromire street
# Press 4) Awolowo road(From Ikeja inside)>>>>>>>>>>>>>>>>>>>>> 1
# You have decided to calculate the traffic time for Allen Avenue
# "Press 0) For Morning
#        Press 1) for evening>>>>>.0
# Enter the time(seperated by comma(6:30 is 6,30))>>>>6,40
# "Enter weekday()>>>>:
#     Enter 1 for Monday
#     Enter 2 for Tuesday
#     Enter 3 for Wednesday
#     Enter 4 for Thursday
#     Enter 5 for Friday
#     Enter 6 for Weekend>>>>>>>>>:6
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-467582608283> in <module>
#     102     print("The Calculated period is green time is:>>>>",t, "Seconds")
#     103 if day==1 and time=="7,00" or "7":
# --> 104     m=df1.iloc[15]["WKD 1"]
#     105     n=dfa.iloc[1]["Intensity"]
#     106     t=m/(n*math.factorial(3))
# ...
